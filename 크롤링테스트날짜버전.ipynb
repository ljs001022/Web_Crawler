# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime

# 직업 게시판 URL을 찾는 함수
def get_job_board_url(job_name):
    main_url = "https://lostark.inven.co.kr/"
    target_base_url = "https://www.inven.co.kr"  # 링크의 베이스 URL
    
    # 메인 페이지에서 게시판 목록 페이지로 이동
    response = requests.get(main_url)
    response.raise_for_status()  # 요청 에러 확인
    
    # HTML 파싱
    soup = BeautifulSoup(response.text, "html.parser")
    
    # 입력받은 직업 이름으로 링크 검색
    job_link = None
    links = soup.find_all("a", href=True)
    for link in links:
        if job_name in link.text:
            job_link = link.get("href")
            break
    
    if job_link:
        # 링크가 절대 경로인지 확인하고, 상대 경로인 경우에만 base URL 추가
        if not job_link.startswith("http"):
            full_url = target_base_url + job_link
        else:
            full_url = job_link
        return full_url
    else:
        return None

# 이모티콘 포함 글 제목 개수와 전체 글 개수를 세는 함수
def count_emoji_titles(job_board_url, input_date):
    emoji_pattern = re.compile(r'[●▅]')  # 이모티콘 패턴 정의
    emoji_count = 0
    total_count = 0  # 전체 글 개수 초기화
    
    input_date_obj = datetime.strptime(input_date, "%m-%d")  # input_date를 datetime 객체로 변환
    page = 1
    while True:
        print(f"{page} 페이지 크롤링")
        # 각 페이지의 URL 구성
        page_url = f"{job_board_url}?p={page}"
        response = requests.get(page_url)
        response.raise_for_status()  # 요청 에러 확인
        
        # HTML 파싱
        soup = BeautifulSoup(response.text, "html.parser")
        
        # 게시글 정보가 포함된 <tr> 요소 추출
        rows = soup.find_all("tr", class_="")
        
        # 각 <tr>에서 게시글 정보 확인
        for row in rows:
            date_tag = row.find("td", class_="date")
            if date_tag:
                date_str = date_tag.text.strip()  # 날짜 문자열 추출
                try:
                    date_obj = datetime.strptime(date_str, "%H:%M")  # 시간은 오늘 날짜로 간주
                    # 오늘 날짜와 결합
                    date_obj = date_obj.replace(year=datetime.today().year)
                    
                    # input_date보다 빠른 날짜면 종료
                    if date_obj < input_date_obj:
                        return emoji_count, total_count  # while 루프 종료
                
                except ValueError:
                    continue  # 날짜 파싱 오류 시 건너뛰기

            # 글 제목 요소 추출
            title_tag = row.find("a", class_="subject-link")
            print(title_tag)
            if title_tag:
                total_count += 1
                # 글 제목에서 이모티콘 포함 여부 확인
                if emoji_pattern.search(title_tag.text):  
                    print(title_tag.text)  # 이모티콘이 포함된 제목 출력
                    emoji_count += 1

        page += 1  # 다음 페이지로 이동
    return emoji_count, total_count

# 사용자 입력
job_name = input("직업 이름을 입력하세요: ")
input_date = input("날짜를 입력하세요: ")

# 게시판 URL 가져오기
job_board_url = get_job_board_url(job_name)

if job_board_url:
    # 이모티콘이 포함된 글 제목의 개수와 전체 글 개수 확인
    print(f"현재 검색한 직업은 {job_name}입니다")
    emoji_title_count, total_title_count = count_emoji_titles(job_board_url, input_date)
    print(f"전체 글 제목의 개수: {total_title_count}")
    print(f"이모티콘이 포함된 글 제목의 개수: {emoji_title_count}")
else:
    print("해당 직업의 게시판을 찾을 수 없습니다.")
# Out:
# 현재 검색한 직업은 인파이터입니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 95
#      92 if job_board_url:
#      93     # 이모티콘이 포함된 글 제목의 개수와 전체 글 개수 확인
#      94     print(f"현재 검색한 직업은 {job_name}입니다")
# ---> 95     emoji_title_count, total_title_count = count_emoji_titles(job_board_url, input_date)
#      96     print(f"전체 글 제목의 개수: {total_title_count}")
#      97     print(f"이모티콘이 포함된 글 제목의 개수: {emoji_title_count}")
#
# Cell In[4], line 47, in count_emoji_titles(job_board_url, input_date)
#      44 while True:
#      45     # 각 페이지의 URL 구성
#      46     page_url = f"{job_board_url}?p={page}"
# ---> 47     response = requests.get(page_url)
#      48     response.raise_for_status()  # 요청 에러 확인
#      50     # HTML 파싱
#
# File c:\Users\Dev_Lee\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Dev_Lee\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Dev_Lee\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File c:\Users\Dev_Lee\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:481, in Session.prepare_request(self, request)
#     479 auth = request.auth
#     480 if self.trust_env and not auth and not self.auth:
# --> 481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
#     484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#    (...)
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#
# File c:\Users\Dev_Lee\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\utils.py:227, in get_netrc_auth(url, raise_errors)
#     221 except KeyError:
#     222     # os.path.expanduser can fail when $HOME is undefined and
#     223     # getpwuid fails. See https://bugs.python.org/issue20164 &
#     224     # https://github.com/psf/requests/issues/1846
#     225     return
# --> 227 if os.path.exists(loc):
#     228     netrc_path = loc
#     229     break
#
# KeyboardInterrupt:
